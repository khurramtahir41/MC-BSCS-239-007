# %% [markdown]
# 1:Print program

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# 2:Print Integer

# %%
print(3)
# Out:
# 3

# %% [markdown]
# 3:Print Addition 3+2

# %%
print(3+2)
# Out:
# 5

# %% [markdown]
# 4:Store value in a variable

# %%
name="MKB"
age=20
print(name,age)
# Out:
# MKB 20

# %% [markdown]
# 5:comment single line and paragraph

# %%
print("#This is a comment")
# I am learning  python
#"""I am learning python
# It is very easy language
# We are using  Visual studio code"""
# Out:
# #This is a comment

# %% [markdown]
# 6:Store More Values

# %%
X,Y,Z = "a","b","c"
print(X)
print(Y)
print(Z)
# Out:
# a
# b
# c

# %% [markdown]
# 7:Same value to multiple variable in one line

# %%
a=b=c="Python"

print(b)
# Out:
# Python

# %% [markdown]
# 8:declare variable and arithmetic function

# %%
a=55
b=67
print(a+b)
print(a-b)
print(a*b)
print(a/b)
# Out:
# 122
# -12
# 3685
# 0.8208955223880597

# %% [markdown]
# 9:Use of Dictionary

# %%
dict = {
    "name": "Khurram",
    "age": 25,
    "city": "Multan"
}
print(dict)
# Out:
# {'name': 'Khurram', 'age': 25, 'city': 'Multan'}
